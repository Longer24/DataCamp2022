# %% [markdown]
# # PCA

# %%
import numpy as np
import pandas as pd
from apyori import apriori
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %matplotlib notebook

# %%
(X, y) = load_breast_cancer(return_X_y=True)
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)
pca = PCA(n_components=2)
Z = pca.fit_transform(X_scaled)
Z.shape
# Out:
# (569, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(Z, y, random_state=2021)
clf = LogisticRegression().fit(X_train, y_train)
y_predicted = clf.predict(Z)
print('Accuracy on training set: {:.2f}'.format(clf.score(X_train, y_train)))
print('Accuracy on test set: {:.2f}'.format(clf.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.96
# Accuracy on test set: 0.96

# %%
colors = np.array(['blue','yellow'])
plt.figure()
plt.xlabel('First principle component')
plt.ylabel('Second principle component')
plt.scatter(Z[:,0], Z[:,1], s= 40, c=colors[y_predicted], edgecolors='black', label='negative', alpha = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Apriori

# %%
df = pd.read_csv('Groceries_dataset.csv')
df.head ()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
len(df)
# Out:
# 38765

# %%
plt.figure()
dist = [len(g) for k, g in df.groupby(['Member_number', 'Date'])]
plt.hist(dist)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.008e+04, 2.698e+03, 1.390e+03, 3.440e+02, 1.750e+02, 8.000e+01,
#         1.450e+02, 5.000e+01, 0.000e+00, 1.000e+00]),
#  array([ 2. ,  2.9,  3.8,  4.7,  5.6,  6.5,  7.4,  8.3,  9.2, 10.1, 11. ]),
#  <BarContainer object of 10 artists>)

# %%
trans = [(k,g) for k, g in df.groupby(['Member_number', 'Date'])]
#plt.hist(dist)
transactions = [list(i[1]['itemDescription']) for i in trans]

df = pd.DataFrame (transactions)
df= df.fillna(0)

transs= df.values.tolist()
trans_stripped = [[item for item in tr if item] for tr in transs]
trans_stripped[:5]
# Out:
# [['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
#  ['whole milk', 'pastry', 'salty snack'],
#  ['canned beer', 'misc. beverages'],
#  ['sausage', 'hygiene articles'],
#  ['soda', 'pickled vegetables']]

# %%
rules = list(apriori(trans_stripped, min_support = 0.001, min_confidence = 0.1, min_lift = 1.2, min_length = 1))
len(rules), rules
# Out:
# (13,
#  [RelationRecord(items=frozenset({'chewing gum', 'yogurt'}), support=0.001403461872619127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chewing gum'}), items_add=frozenset({'yogurt'}), confidence=0.11666666666666667, lift=1.358508430609598)]),
#   RelationRecord(items=frozenset({'detergent', 'yogurt'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'detergent'}), items_add=frozenset({'yogurt'}), confidence=0.12403100775193798, lift=1.4442614544686756)]),
#   RelationRecord(items=frozenset({'flour', 'tropical fruit'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour'}), items_add=frozenset({'tropical fruit'}), confidence=0.10958904109589042, lift=1.6171408500175626)]),
#   RelationRecord(items=frozenset({'herbs', 'yogurt'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs'}), items_add=frozenset({'yogurt'}), confidence=0.10759493670886075, lift=1.2528739595133722)]),
#   RelationRecord(items=frozenset({'oil', 'soda'}), support=0.001804450979081735, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'soda'}), confidence=0.12107623318385649, lift=1.246843549298035)]),
#   RelationRecord(items=frozenset({'rolls/buns', 'packaged fruit/vegetables'}), support=0.0012029673193878234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables'}), items_add=frozenset({'rolls/buns'}), confidence=0.14173228346456695, lift=1.2884205087972755)]),
#   RelationRecord(items=frozenset({'rolls/buns', 'processed cheese'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'rolls/buns'}), confidence=0.14473684210526316, lift=1.315733516659206)]),
#   RelationRecord(items=frozenset({'root vegetables', 'processed cheese'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'root vegetables'}), confidence=0.10526315789473686, lift=1.5130188583851563)]),
#   RelationRecord(items=frozenset({'rolls/buns', 'seasonal products'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'seasonal products'}), items_add=frozenset({'rolls/buns'}), confidence=0.14150943396226415, lift=1.2863946903872165)]),
#   RelationRecord(items=frozenset({'yogurt', 'soft cheese'}), support=0.0012697988371315912, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soft cheese'}), items_add=frozenset({'yogurt'}), confidence=0.12666666666666665, lift=1.4749520103761347)]),
#   RelationRecord(items=frozenset({'rolls/buns', 'whole milk', 'sausage'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rolls/buns', 'sausage'}), items_add=frozenset({'whole milk'}), confidence=0.2125, lift=1.345593525179856)]),
#   RelationRecord(items=frozenset({'soda', 'whole milk', 'sausage'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'soda'}), confidence=0.11940298507462688, lift=1.2296124333596987)]),
#   RelationRecord(items=frozenset({'whole milk', 'yogurt', 'sausage'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'yogurt'}), confidence=0.16417910447761194, lift=1.9117602648237413), OrderedStatistic(items_base=frozenset({'yogurt', 'sausage'}), items_add=frozenset({'whole milk'}), confidence=0.2558139534883721, lift=1.6198663504217148), OrderedStatistic(items_base=frozenset({'whole milk', 'yogurt'}), items_add=frozenset({'sausage'}), confidence=0.1317365269461078, lift=2.1829165589087607)])])

# %%
rules_trans = []

# %%
def print_rules(rules):
    for rule in rules:
        rule_det = {}
        print ('rule.items=', list(rule.items))
        rule_det['items']=rule.items
        print ('rule.support=',rule.support)
        rule_det['support']=rule.support

        for os in rule.ordered_statistics:
            rule_det['items_base']=os.items_base
            print ('\titems_base=', list(os.items_base))
            rule_det['items_add']=os.items_add
            print ('\tlifted_item =', list(os.items_add))
            rule_det['lift']=os.lift
            print ('\tlift=', os.lift)
            print ('\tconfidence (i.e. cond prob {} if {})='.format(list(os.items_add), list(os.items_base)), os.confidence)
            print ('\n')
        rules_trans.append(rule_det)
print_rules(rules)
# Out:
# rule.items= ['chewing gum', 'yogurt']
# rule.support= 0.001403461872619127
# 	items_base= ['chewing gum']
# 	lifted_item = ['yogurt']
# 	lift= 1.358508430609598
# 	confidence (i.e. cond prob ['yogurt'] if ['chewing gum'])= 0.11666666666666667
#
#
# rule.items= ['detergent', 'yogurt']
# rule.support= 0.0010693042839002875
# 	items_base= ['detergent']
# 	lifted_item = ['yogurt']
# 	lift= 1.4442614544686756
# 	confidence (i.e. cond prob ['yogurt'] if ['detergent'])= 0.12403100775193798
#
#
# rule.items= ['flour', 'tropical fruit']
# rule.support= 0.0010693042839002875
# 	items_base= ['flour']
# 	lifted_item = ['tropical fruit']
# 	lift= 1.6171408500175626
# 	confidence (i.e. cond prob ['tropical fruit'] if ['flour'])= 0.10958904109589042
#
#
# rule.items= ['herbs', 'yogurt']
# rule.support= 0.0011361358016440553
# 	items_base= ['herbs']
# 	lifted_item = ['yogurt']
# 	lift= 1.2528739595133722
# 	confidence (i.e. cond prob ['yogurt'] if ['herbs'])= 0.10759493670886075
#
#
# rule.items= ['oil', 'soda']
# rule.support= 0.001804450979081735
# 	items_base= ['oil']
# 	lifted_item = ['soda']
# 	lift= 1.246843549298035
# 	confidence (i.e. cond prob ['soda'] if ['oil'])= 0.12107623318385649
#
#
# rule.items= ['rolls/buns', 'packaged fruit/vegetables']
# rule.support= 0.0012029673193878234
# 	items_base= ['packaged fruit/vegetables']
# 	lifted_item = ['rolls/buns']
# 	lift= 1.2884205087972755
# 	confidence (i.e. cond prob ['rolls/buns'] if ['packaged fruit/vegetables'])= 0.14173228346456695
#
#
# rule.items= ['rolls/buns', 'processed cheese']
# rule.support= 0.0014702933903628951
# 	items_base= ['processed cheese']
# 	lifted_item = ['rolls/buns']
# 	lift= 1.315733516659206
# 	confidence (i.e. cond prob ['rolls/buns'] if ['processed cheese'])= 0.14473684210526316
#
#
# rule.items= ['root vegetables', 'processed cheese']
# rule.support= 0.0010693042839002875
# 	items_base= ['processed cheese']
# 	lifted_item = ['root vegetables']
# 	lift= 1.5130188583851563
# 	confidence (i.e. cond prob ['root vegetables'] if ['processed cheese'])= 0.10526315789473686
#
#
# rule.items= ['rolls/buns', 'seasonal products']
# rule.support= 0.0010024727661565194
# 	items_base= ['seasonal products']
# 	lifted_item = ['rolls/buns']
# 	lift= 1.2863946903872165
# 	confidence (i.e. cond prob ['rolls/buns'] if ['seasonal products'])= 0.14150943396226415
#
#
# rule.items= ['yogurt', 'soft cheese']
# rule.support= 0.0012697988371315912
# 	items_base= ['soft cheese']
# 	lifted_item = ['yogurt']
# 	lift= 1.4749520103761347
# 	confidence (i.e. cond prob ['yogurt'] if ['soft cheese'])= 0.12666666666666665
#
#
# rule.items= ['rolls/buns', 'whole milk', 'sausage']
# rule.support= 0.0011361358016440553
# 	items_base= ['rolls/buns', 'sausage']
# 	lifted_item = ['whole milk']
# 	lift= 1.345593525179856
# 	confidence (i.e. cond prob ['whole milk'] if ['rolls/buns', 'sausage'])= 0.2125
#
#
# rule.items= ['soda', 'whole milk', 'sausage']
# rule.support= 0.0010693042839002875
# 	items_base= ['whole milk', 'sausage']
# 	lifted_item = ['soda']
# 	lift= 1.2296124333596987
# 	confidence (i.e. cond prob ['soda'] if ['whole milk', 'sausage'])= 0.11940298507462688
#
#
# rule.items= ['whole milk', 'yogurt', 'sausage']
# rule.support= 0.0014702933903628951
# 	items_base= ['whole milk', 'sausage']
# 	lifted_item = ['yogurt']
# 	lift= 1.9117602648237413
# 	confidence (i.e. cond prob ['yogurt'] if ['whole milk', 'sausage'])= 0.16417910447761194
#
#
# 	items_base= ['yogurt', 'sausage']
# 	lifted_item = ['whole milk']
# 	lift= 1.6198663504217148
# 	confidence (i.e. cond prob ['whole milk'] if ['yogurt', 'sausage'])= 0.2558139534883721
#
#
# 	items_base= ['whole milk', 'yogurt']
# 	lifted_item = ['sausage']
# 	lift= 2.1829165589087607
# 	confidence (i.e. cond prob ['sausage'] if ['whole milk', 'yogurt'])= 0.1317365269461078

# %%
top_10_lift = np.sort([x['lift'] for x in rules_trans])[::-1][:10]
top_10_rules = [rule for rule in rules_trans if rule['lift'] in top_10_lift]
top_10_rules
# Out:
# [{'items': frozenset({'chewing gum', 'yogurt'}),
#   'support': 0.001403461872619127,
#   'items_base': frozenset({'chewing gum'}),
#   'items_add': frozenset({'yogurt'}),
#   'lift': 1.358508430609598},
#  {'items': frozenset({'detergent', 'yogurt'}),
#   'support': 0.0010693042839002875,
#   'items_base': frozenset({'detergent'}),
#   'items_add': frozenset({'yogurt'}),
#   'lift': 1.4442614544686756},
#  {'items': frozenset({'flour', 'tropical fruit'}),
#   'support': 0.0010693042839002875,
#   'items_base': frozenset({'flour'}),
#   'items_add': frozenset({'tropical fruit'}),
#   'lift': 1.6171408500175626},
#  {'items': frozenset({'packaged fruit/vegetables', 'rolls/buns'}),
#   'support': 0.0012029673193878234,
#   'items_base': frozenset({'packaged fruit/vegetables'}),
#   'items_add': frozenset({'rolls/buns'}),
#   'lift': 1.2884205087972755},
#  {'items': frozenset({'processed cheese', 'rolls/buns'}),
#   'support': 0.0014702933903628951,
#   'items_base': frozenset({'processed cheese'}),
#   'items_add': frozenset({'rolls/buns'}),
#   'lift': 1.315733516659206},
#  {'items': frozenset({'processed cheese', 'root vegetables'}),
#   'support': 0.0010693042839002875,
#   'items_base': frozenset({'processed cheese'}),
#   'items_add': frozenset({'root vegetables'}),
#   'lift': 1.5130188583851563},
#  {'items': frozenset({'rolls/buns', 'seasonal products'}),
#   'support': 0.0010024727661565194,
#   'items_base': frozenset({'seasonal products'}),
#   'items_add': frozenset({'rolls/buns'}),
#   'lift': 1.2863946903872165},
#  {'items': frozenset({'soft cheese', 'yogurt'}),
#   'support': 0.0012697988371315912,
#   'items_base': frozenset({'soft cheese'}),
#   'items_add': frozenset({'yogurt'}),
#   'lift': 1.4749520103761347},
#  {'items': frozenset({'rolls/buns', 'sausage', 'whole milk'}),
#   'support': 0.0011361358016440553,
#   'items_base': frozenset({'rolls/buns', 'sausage'}),
#   'items_add': frozenset({'whole milk'}),
#   'lift': 1.345593525179856},
#  {'items': frozenset({'sausage', 'whole milk', 'yogurt'}),
#   'support': 0.0014702933903628951,
#   'items_base': frozenset({'whole milk', 'yogurt'}),
#   'items_add': frozenset({'sausage'}),
#   'lift': 2.1829165589087607}]
